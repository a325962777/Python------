# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
cities.csv ל-DataFrame ב-pandas.
# Out:
#   Cell In[3], line 1
#     cities.csv ל-DataFrame ב-pandas.
#                ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df_other = pd.read_csv('cities.csv')

# %%
df_other
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"  "EW"  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                  City""  State
# 0          "Youngstown"     OH
# 1             "Yankton"     SD
# 2              "Yakima"     WA
# 3           "Worcester"     MA
# 4     "Wisconsin Dells"     WI
# ..                  ...    ...
# ...

# %%
df_other.isnull().sum().sum
# Out:
# <bound method Series.sum of LatD       0
#  "LatM"    0
# LatS       0
# NS         0
# LonD       0
#  LonM""    0
#  "LonS"    0
#  "EW"      0
#  City""    0
#  State     0
# dtype: int64>

# %%
df_other.LatD = df_other.LatD.fillna(0)

# %%
df_other
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"  "EW"  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                  City""  State
# 0          "Youngstown"     OH
# 1             "Yankton"     SD
# 2              "Yakima"     WA
# 3           "Worcester"     MA
# 4     "Wisconsin Dells"     WI
# ..                  ...    ...
# ...

# %%
df_other.dropna(axis=0)
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"  "EW"  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                  City""  State
# 0          "Youngstown"     OH
# 1             "Yankton"     SD
# 2              "Yakima"     WA
# 3           "Worcester"     MA
# 4     "Wisconsin Dells"     WI
# ..                  ...    ...
# ...

# %%
df_other['LatD'].mean()
# Out:
# 38.8203125

# %%
df_other['LatD'].max()
# Out:
# 50

# %%
df_other['LatD'].min()
# Out:
# 26

# %%
df_other['yachas']=df_other['LatD']/df_other['LatS']
df_other
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"  "EW"  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                  City""  State    yachas
# 0          "Youngstown"     OH  0.694915
# 1             "Yankton"     SD  0.875000
# 2              "Yakima"     WA  0.779661
# 3           "Worcester"     MA  3.500000
# ...

# %%
df_other.sort_valuse(by=['LatD'],descending=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11812\3741221661.py in ?()
# ----> 1 df_other.sort_valuse(by=['LatD'],descending=True)
#
# C:\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort_valuse'

# %%
df_other[df_other['LatD'] == 41]
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"  "EW"           City""  \
# 0      41        5    59   "N"    80       39        0   "W"     "Youngstown"
# 11     41       15     0   "N"    77        0        0   "W"             null
# 18     41       25    11   "N"   122       23       23   "W"           "Weed"
# 25     41       32    59   "N"    73        3        0   "W"      "Waterbury"
# 27     41       50    59   "N"    79        8       23   "W"         "Warren"
# 49     41       39     0   "N"    83       32       24   "W"         "Toledo"
# 69     41       40    48   "N"    86       15        0   "W"     "South Bend"
# 79     41       24    35   "N"    75       40       11   "W"       "Scranton"
# 80     41       52    11   "N"   103       39       36   "W"    "Scottsbluff"
# 91     41       27     0   "N"    82       42       35   "W"       "Sandusky"
# 114    41       35    24   "N"   109       13       48   "W"   "Rock Springs"
# ...

# %%
simple2 = pd.DataFrame(df_other)
simple2
# Out:
#      LatD   "LatM"  LatS    NS  LonD   LonM""   "LonS"  "EW"  \
# 0      41        5    59   "N"    80       39        0   "W"
# 1      42       52    48   "N"    97       23       23   "W"
# 2      46       35    59   "N"   120       30       36   "W"
# 3      42       16    12   "N"    71       48        0   "W"
# 4      43       37    48   "N"    89       46       11   "W"
# ..    ...      ...   ...   ...   ...      ...      ...   ...
# 123    39       31    12   "N"   119       48       35   "W"
# 124    50       25    11   "N"   104       39        0   "W"
# 125    40       10    48   "N"   122       14       23   "W"
# 126    40       19    48   "N"    75       55       48   "W"
# 127    41        9    35   "N"    81       14       23   "W"
#
#                  City""  State    yachas
# 0          "Youngstown"     OH  0.694915
# 1             "Yankton"     SD  0.875000
# 2              "Yakima"     WA  0.779661
# 3           "Worcester"     MA  3.500000
# ...
