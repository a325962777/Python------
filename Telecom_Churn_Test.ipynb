# %% [markdown]
# #### 1. Dataframe basics

# %% [markdown]
# #### 1.1. Import pandas and reffered the package as pd + Load "telecom_churn.csv" and assign in to the variable df <span style= color:#0033cc>(3 points)</span>

# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.2.1-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\python310\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\python310\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.1-cp310-cp310-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.2.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df=pd.read_csv('telecom_churn.csv')
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# ...                      ...    ...
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False
#
# [3333 rows x 20 columns]

# %% [markdown]
# #### 1.2 Return the column labels/names <span style= color:#0033cc>(2 points)</span>

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# #### 1.3 Print the df shape <span style= color:#0033cc>(3 points)</span>

# %%
df.shape
# Out:
# (3333, 20)

# %% [markdown]
# #### 2. What is the total day calls given by state and area code?

# %% [markdown]
# #### 2.1 Group the df by state and area code (assign it to grouped variable). <span style= color:#0033cc>(5 points)</span>

# %%
groupBy=df.groupby(['State','Area code'])
groupBy

# %% [markdown]
# #### 2.2 Use agg with the desired function sum to get the final answer (assign it to telecom_agg variable).<span style= color:#0033cc>(5 points)</span>

# %%
telecom_agg=groupBy.agg({'Total day calls':['sum']})
telecom_agg
# Out:
#                 Total day calls
#                             sum
# State Area code
# AK    408                  1342
#       415                  2357
#       510                  1255
# AL    408                  2524
#       415                  4090
# ...                         ...
# WV    415                  5474
#       510                  3491
# WY    408                  1659
#       415                  4205
#       510                  2007
#
# [153 rows x 1 columns]

# %% [markdown]
# #### 2.3 Reset the group by index <span style= color:#0033cc>(3 points)</span>

# %%
df.reset_index(inplace=True)

# %% [markdown]
# #### 2.4 Use head function to review the first 10 telecom_agg rows <span style= color:#0033cc>(3 points)</span>

# %%
telecom_agg.head(10)
# Out:
#                 Total day calls
#                             sum
# State Area code
# AK    408                  1342
#       415                  2357
#       510                  1255
# AL    408                  2524
#       415                  4090
#       510                  1314
# AR    408                  1382
#       415                  2756
#       510                  1480
# AZ    408                  1452

# %% [markdown]
# #### 3. Users Churn rate

# %% [markdown]
# #### 3.1 Change "Churn" column type to an integer: <span style= color:#0033cc>(3 points)</span>

# %%
df.astype({'Churn':'int32'})
df
# Out:
#       index State  Account length  Area code International plan  \
# 0         0    KS             128        415                 No
# 1         1    OH             107        415                 No
# 2         2    NJ             137        415                 No
# 3         3    OH              84        408                Yes
# 4         4    OK              75        415                Yes
# ...     ...   ...             ...        ...                ...
# 3328   3328    AZ             192        415                 No
# 3329   3329    WV              68        415                 No
# 3330   3330    RI              28        510                 No
# 3331   3331    CT             184        510                Yes
# 3332   3332    TN              74        415                 No
#
#      Voice mail plan  Number vmail messages  Total day minutes  \
# 0                Yes                     25              265.1
# 1                Yes                     26              161.6
# 2                 No                      0              243.4
# 3                 No                      0              299.4
# 4                 No                      0              166.7
# ...              ...                    ...                ...
# 3328             Yes                     36              156.2
# 3329              No                      0              231.1
# 3330              No                      0              180.8
# 3331              No                      0              213.8
# 3332             Yes                     25              234.4
#
#       Total day calls  Total day charge  ...  Total eve calls  \
# 0                 110             45.07  ...               99
# 1                 123             27.47  ...              103
# 2                 114             41.38  ...              110
# 3                  71             50.90  ...               88
# 4                 113             28.34  ...              122
# ...               ...               ...  ...              ...
# 3328               77             26.55  ...              126
# 3329               57             39.29  ...               55
# 3330              109             30.74  ...               58
# 3331              105             36.35  ...               84
# 3332              113             39.85  ...               82
#
#       Total eve charge  Total night minutes  Total night calls  \
# 0                16.78                244.7                 91
# 1                16.62                254.4                103
# 2                10.30                162.6                104
# 3                 5.26                196.9                 89
# 4                12.61                186.9                121
# ...                ...                  ...                ...
# 3328             18.32                279.1                 83
# 3329             13.04                191.3                123
# 3330             24.55                191.9                 91
# 3331             13.57                139.2                137
# 3332             22.60                241.4                 77
#
#       Total night charge  Total intl minutes  Total intl calls  \
# 0                  11.01                10.0                 3
# 1                  11.45                13.7                 3
# 2                   7.32                12.2                 5
# 3                   8.86                 6.6                 7
# 4                   8.41                10.1                 3
# ...                  ...                 ...               ...
# 3328               12.56                 9.9                 6
# 3329                8.61                 9.6                 4
# 3330                8.64                14.1                 6
# 3331                6.26                 5.0                10
# 3332               10.86                13.7                 4
#
#       Total intl charge  Customer service calls  Churn
# 0                  2.70                       1  False
# 1                  3.70                       1  False
# 2                  3.29                       0  False
# 3                  1.78                       2  False
# 4                  2.73                       3  False
# ...                 ...                     ...    ...
# 3328               2.67                       2  False
# 3329               2.59                       3  False
# 3330               3.81                       2  False
# 3331               1.35                       2  False
# 3332               3.70                       0  False
#
# [3333 rows x 21 columns]

# %% [markdown]
# #### 3.2 what is the users "churn rate" in our dataframe? <span style= color:#0033cc>(5 points)</span>
# Hint: the churn rate formula can be calculated as the "number of churned" divided by the "total number of customers".

# %%
avg = df['Churn'].mean()
avg
df['Churn']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: Churn, Length: 3333, dtype: bool

# %% [markdown]
# #### 3.3  How the charn rate can affect on the company? <span style= color:#0033cc>(3 points)</span>

# %% [markdown]
# כאשר משתמשים עוזבים את החברה נגרמים הפסדים

# %% [markdown]
# #### 3.4 How much time (on average) do churned users spend on the phone during daytime? <span style= color:#0033cc>(5 points)</span>
# Hint: filter churn column when the value of churn equal to 1

# %%
g = df[df['Churn']==1]
g['Total day minutes'].mean()
# Out:
# 206.91407867494823

# %% [markdown]
# #### 3.5 What is the maximum length of international calls among loyal users who do not have an international plan? ('International plan' == 'No') <span style= color:#0033cc>(5 points)</span>
# Hint: 2 filters conditions,churn equal to 0 and international plan equal to no

# %%
n=df[df['International plan'] == 'No'][df['Churn'] == 1]['Total intl minutes'].max()
n
# Out:
# C:\Users\huser\AppData\Local\Temp\ipykernel_11104\566194016.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   n=df[df['International plan'] == 'No'][df['Churn'] == 1]['Total intl minutes'].max()
# 18.3

# %% [markdown]
# #### 4. Select top 3 international plan subscribers and non subscribers with the most intl calls

# %% [markdown]
# #### 4.1. Build a function top which attributes df, n (for the top n) and column. In this function use sort_values to sort the values in the column specified. <span style= color:#0033cc>(10 points)</span>
# Note: Do not apply the function on the whole data frame (e.i. top(df, n=3)) as the output will be the top 3 regardless of subscribers and non-subscribers.

# %%
def top(df,n=3):
    aa = df[df['International plan'] == 'No'][df['Churn'] == 1].sort_values(by='Total intl minutes').head(n)
    return aa
top(df)
# Out:
# C:\Users\huser\AppData\Local\Temp\ipykernel_4396\2138967051.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   aa = df[df['International plan'] == 'No'][df['Churn'] == 1].sort_values(by='Total intl minutes').head(n)
#       index State  Account length  Area code International plan  \
# 397     397    OR              94        415                 No
# 3247   3247    OK             146        510                 No
# 1373   1373    SC             108        415                 No
#
#      Voice mail plan  Number vmail messages  Total day minutes  \
# 397               No                      0              234.4
# 3247              No                      0              138.4
# 1373              No                      0              112.0
#
#       Total day calls  Total day charge  ...  Total eve calls  \
# 397               103             39.85  ...              109
# 3247              104             23.53  ...              122
# 1373              105             19.04  ...              110
#
#       Total eve charge  Total night minutes  Total night calls  \
# 397              23.74                234.2                121
# 3247             13.51                 47.4                 73
# 1373             16.46                208.9                 93
#
#       Total night charge  Total intl minutes  Total intl calls  \
# 397                10.54                 2.0                 2
# 3247                2.13                 3.9                 9
# 1373                9.40                 4.1                 4
#
#       Total intl charge  Customer service calls  Churn
# 397                0.54                       1   True
# 3247               1.05                       4   True
# 1373               1.11                       4   True
#
# [3 rows x 21 columns]

# %% [markdown]
# #### 4.2. Group the df dataframe by 'International plan' and use apply(top) to apply this function. <span style= color:#0033cc>(5 points)</span>

# %%
df_top = df.groupby('International plan').apply(lambda x: top(x,3))
df_top
# Out:
# C:\Users\huser\AppData\Local\Temp\ipykernel_4396\2138967051.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   aa = df[df['International plan'] == 'No'][df['Churn'] == 1].sort_values(by='Total intl minutes').head(n)
# C:\Users\huser\AppData\Local\Temp\ipykernel_4396\1685974093.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_top = df.groupby('International plan').apply(lambda x: top(x,3))
#                          index State  Account length  Area code  \
# International plan
# No                 397     397    OR              94        415
#                    3247   3247    OK             146        510
#                    1373   1373    SC             108        415
#
#                         International plan Voice mail plan  \
# International plan
# No                 397                  No              No
#                    3247                 No              No
#                    1373                 No              No
#
#                          Number vmail messages  Total day minutes  \
# International plan
# No                 397                       0              234.4
#                    3247                      0              138.4
#                    1373                      0              112.0
#
#                          Total day calls  Total day charge  ...  \
# International plan                                          ...
# No                 397               103             39.85  ...
#                    3247              104             23.53  ...
#                    1373              105             19.04  ...
#
#                          Total eve calls  Total eve charge  \
# International plan
# No                 397               109             23.74
#                    3247              122             13.51
#                    1373              110             16.46
#
#                          Total night minutes  Total night calls  \
# International plan
# No                 397                 234.2                121
#                    3247                 47.4                 73
#                    1373                208.9                 93
#
#                          Total night charge  Total intl minutes  \
# International plan
# No                 397                10.54                 2.0
#                    3247                2.13                 3.9
#                    1373                9.40                 4.1
#
#                          Total intl calls  Total intl charge  \
# International plan
# No                 397                  2               0.54
#                    3247                 9               1.05
#                    1373                 4               1.11
#
#                          Customer service calls  Churn
# International plan
# No                 397                        1   True
#                    3247                       4   True
#                    1373                       4   True
#
# [3 rows x 21 columns]

# %% [markdown]
# #### 5. pd.crosstab

# %% [markdown]
# #### 5.1 how the observations in our sample are normalized (divide each value by the sum of the values) in the context of two variables - Churn and Voice mail plan. To do so, build a contingency table using the crosstab method. <span style= color:#0033cc>(6 points)</span>
# Hint: To normalize using all values, simply set normalize=True

# %%
df_crosstab = pd.crosstab(df['Churn'],df['Voice mail plan'], normalize=True)
df_crosstab
# Out:
# Voice mail plan        No       Yes
# Churn
# False            0.602460  0.252625
# True             0.120912  0.024002

# %% [markdown]
# #### 5.2 What is the conclustion of most of users regarding voice mail usage? <span style= color:#0033cc>(4 points)</span>

# %% [raw]
# dff=pd.crosstab(df['Churn'],df['Voice mail plan']) dff

# %% [markdown]
# #### 6. Columns calculations

# %% [markdown]
# #### 6.1 Add a column name 'total_charge', and get the total charge by sum all the charge columns <span style= color:#0033cc>(7 points)</span>

# %%
listSum=['Total day charge','Total eve charge','Total intl charge','Total night charge']
df['total_charge'] = df[listSum].sum(axis=1)
df
# Out:
#       index State  Account length  Total_charge  Area code International plan  \
# 0         0    KS             128      599190.4        415                 No
# 1         1    OH             107      599190.4        415                 No
# 2         2    NJ             137      599190.4        415                 No
# 3         3    OH              84      599190.4        408                Yes
# 4         4    OK              75      599190.4        415                Yes
# ...     ...   ...             ...           ...        ...                ...
# 3328   3328    AZ             192      599190.4        415                 No
# 3329   3329    WV              68      599190.4        415                 No
# 3330   3330    RI              28      599190.4        510                 No
# 3331   3331    CT             184      599190.4        510                Yes
# 3332   3332    TN              74      599190.4        415                 No
#
#      Voice mail plan  Number vmail messages  Total day minutes  \
# 0                Yes                     25              265.1
# 1                Yes                     26              161.6
# 2                 No                      0              243.4
# 3                 No                      0              299.4
# 4                 No                      0              166.7
# ...              ...                    ...                ...
# 3328             Yes                     36              156.2
# 3329              No                      0              231.1
# 3330              No                      0              180.8
# 3331              No                      0              213.8
# 3332             Yes                     25              234.4
#
#       Total day calls  ...  Total eve charge  Total night minutes  \
# 0                 110  ...             16.78                244.7
# 1                 123  ...             16.62                254.4
# 2                 114  ...             10.30                162.6
# 3                  71  ...              5.26                196.9
# 4                 113  ...             12.61                186.9
# ...               ...  ...               ...                  ...
# 3328               77  ...             18.32                279.1
# 3329               57  ...             13.04                191.3
# 3330              109  ...             24.55                191.9
# 3331              105  ...             13.57                139.2
# 3332              113  ...             22.60                241.4
#
#       Total night calls  Total night charge  Total intl minutes  \
# 0                    91               11.01                10.0
# 1                   103               11.45                13.7
# 2                   104                7.32                12.2
# 3                    89                8.86                 6.6
# 4                   121                8.41                10.1
# ...                 ...                 ...                 ...
# 3328                 83               12.56                 9.9
# 3329                123                8.61                 9.6
# 3330                 91                8.64                14.1
# 3331                137                6.26                 5.0
# 3332                 77               10.86                13.7
#
#       Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                    3               2.70                       1  False
# 1                    3               3.70                       1  False
# 2                    5               3.29                       0  False
# 3                    7               1.78                       2  False
# 4                    3               2.73                       3  False
# ...                ...                ...                     ...    ...
# 3328                 6               2.67                       2  False
# 3329                 4               2.59                       3  False
# 3330                 6               3.81                       2  False
# 3331                10               1.35                       2  False
# 3332                 4               3.70                       0  False
#
#       total_charge
# 0            75.56
# 1            59.24
# 2            62.29
# 3            66.80
# 4            52.09
# ...            ...
# 3328         60.10
# 3329         63.53
# 3330         67.74
# 3331         57.53
# 3332         77.01
#
# [3333 rows x 23 columns]

# %% [markdown]
# ####  6.2 Add a column name 'Day_charge_pct', and get day charge precentage of total charge by dividing the column 'Total day charge' by the column 'total_charge'. <span style= color:#0033cc>(7 points)</span>

# %%
df['Day_charge_pct'] = df['Total day charge']/df['total_charge']
df
# Out:
#       index State  Account length  Total_charge  Area code International plan  \
# 0         0    KS             128      599190.4        415                 No
# 1         1    OH             107      599190.4        415                 No
# 2         2    NJ             137      599190.4        415                 No
# 3         3    OH              84      599190.4        408                Yes
# 4         4    OK              75      599190.4        415                Yes
# ...     ...   ...             ...           ...        ...                ...
# 3328   3328    AZ             192      599190.4        415                 No
# 3329   3329    WV              68      599190.4        415                 No
# 3330   3330    RI              28      599190.4        510                 No
# 3331   3331    CT             184      599190.4        510                Yes
# 3332   3332    TN              74      599190.4        415                 No
#
#      Voice mail plan  Number vmail messages  Total day minutes  \
# 0                Yes                     25              265.1
# 1                Yes                     26              161.6
# 2                 No                      0              243.4
# 3                 No                      0              299.4
# 4                 No                      0              166.7
# ...              ...                    ...                ...
# 3328             Yes                     36              156.2
# 3329              No                      0              231.1
# 3330              No                      0              180.8
# 3331              No                      0              213.8
# 3332             Yes                     25              234.4
#
#       Total day calls  ...  Total night minutes  Total night calls  \
# 0                 110  ...                244.7                 91
# 1                 123  ...                254.4                103
# 2                 114  ...                162.6                104
# 3                  71  ...                196.9                 89
# 4                 113  ...                186.9                121
# ...               ...  ...                  ...                ...
# 3328               77  ...                279.1                 83
# 3329               57  ...                191.3                123
# 3330              109  ...                191.9                 91
# 3331              105  ...                139.2                137
# 3332              113  ...                241.4                 77
#
#       Total night charge  Total intl minutes  Total intl calls  \
# 0                  11.01                10.0                 3
# 1                  11.45                13.7                 3
# 2                   7.32                12.2                 5
# 3                   8.86                 6.6                 7
# 4                   8.41                10.1                 3
# ...                  ...                 ...               ...
# 3328               12.56                 9.9                 6
# 3329                8.61                 9.6                 4
# 3330                8.64                14.1                 6
# 3331                6.26                 5.0                10
# 3332               10.86                13.7                 4
#
#       Total intl charge  Customer service calls  Churn  total_charge  \
# 0                  2.70                       1  False         75.56
# 1                  3.70                       1  False         59.24
# 2                  3.29                       0  False         62.29
# 3                  1.78                       2  False         66.80
# 4                  2.73                       3  False         52.09
# ...                 ...                     ...    ...           ...
# 3328               2.67                       2  False         60.10
# 3329               2.59                       3  False         63.53
# 3330               3.81                       2  False         67.74
# 3331               1.35                       2  False         57.53
# 3332               3.70                       0  False         77.01
#
#       Day_charge_pct
# 0           0.596480
# 1           0.463707
# 2           0.664312
# 3           0.761976
# 4           0.544058
# ...              ...
# 3328        0.441764
# 3329        0.618448
# 3330        0.453794
# 3331        0.631844
# 3332        0.517465
#
# [3333 rows x 24 columns]

# %% [markdown]
# #### 7. Day charge percentage and state visualization

# %% [markdown]
# #### 7.1 Import matplotlib.pyplot and referred the package as plt <span style= color:#0033cc>(2 points)</span>

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.8.3-cp310-cp310-win_amd64.whl.metadata (5.9 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.0-cp310-cp310-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python310\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\python310\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\python310\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\python310\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached matplotlib-3.8.3-cp310-cp310-win_amd64.whl (7.6 MB)
# Using cached contourpy-1.2.0-cp310-cp310-win_amd64.whl (186 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Installing collected packages: cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.0 cycler-0.12.1 matplotlib-3.8.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### 7.2 create new string list with the name 'my_color' that contains the following colors names: red,green,orange,blue,yellow <span style= color:#0033cc>(4 points)</span>

# %%
my_color = 'yellow, red ,green'
my_color
# Out:
# 'yellow, red ,green'

# %% [markdown]
# #### 7.3 Bar chart plot <span style= color:#0033cc>(10 points)</span>

# %% [markdown]
# 1.Select first 5 rows of the dataframe (use df.iloc[])

# %% [markdown]
# 2.Use <span style= color:blue>df.plot</span> function with kind='bar' and x='State' and y='Day_charge_pct' and color = my_colors to make a simple bar chart plot (of the day chart %).

# %% [markdown]
# 3.Use <span style= color:blue>plt.xlabel("State Code")</span> and <span style= color:blue>plt.ylabel("Day Charge %")</span> to label the corresponding axes

# %%
df.head()
# Out:
#    index State  Account length  Total_charge  Area code International plan  \
# 0      0    KS             128      599190.4        415                 No
# 1      1    OH             107      599190.4        415                 No
# 2      2    NJ             137      599190.4        415                 No
# 3      3    OH              84      599190.4        408                Yes
# 4      4    OK              75      599190.4        415                Yes
#
#   Voice mail plan  Number vmail messages  Total day minutes  Total day calls  \
# 0             Yes                     25              265.1              110
# 1             Yes                     26              161.6              123
# 2              No                      0              243.4              114
# 3              No                      0              299.4               71
# 4              No                      0              166.7              113
#
#    ...  Total night minutes  Total night calls  Total night charge  \
# 0  ...                244.7                 91               11.01
# 1  ...                254.4                103               11.45
# 2  ...                162.6                104                7.32
# 3  ...                196.9                 89                8.86
# 4  ...                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn  total_charge  Day_charge_pct
# 0                       1  False         75.56        0.596480
# 1                       1  False         59.24        0.463707
# 2                       0  False         62.29        0.664312
# 3                       2  False         66.80        0.761976
# 4                       3  False         52.09        0.544058
#
# [5 rows x 24 columns]

# %%
x=df['State']
y=df['Day_charge_pct']
plt.xlabel("State Code")  
plt.ylabel("Day Charge %")
plt.plot(x,y)
